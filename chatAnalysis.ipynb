# %%
import re
import pandas as pd

# %%
f=open("WhatsApp Chat with Ayush Chamoli.txt","r",encoding='utf-8')

# %%
data=f.read()

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
pattern='\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\aksha\AppData\Local\Temp\ipykernel_9968\3706297391.py:1: SyntaxWarning: invalid escape sequence '\d'
#   pattern='\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
messages=re.split(pattern,data)[1:]
messages
# Out:
# ['Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Thanks\n',
#  'Ayush Chamoli: Sorry bhai\n',
#  'Akshat Rai: No problem\n',
#  'Ayush Chamoli: Mein phele bhul gya tha bhejna\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Thanks 😏\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Thanks bruv\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Kitnae log hai class mei\n',
#  'Akshat Rai: Experiment 7 ki observation table aur result bhejdo\n',
#  'Ayush Chamoli: Happy new year bhai❤️\n',
#  'Akshat Rai: Happy new year brother\n',
#  'Akshat Rai: Pura Saal kushiyon ke saath beete\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Sabse Sabhya video yahi hai bhrata\n',
#  'Ayush Chamoli: Bht bdiyaaa😂😂😂\n',
#  'Akshat Rai: Assignment 05 \nLab questions bhejdo\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Assignment 05 bhi bhejdo\n',
#  'Ayush Chamoli: Ruko\n',
#  'Akshat Rai: Assignment 3 aur 4 bhi bhej dena\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Thank you bhai 🥰🥰🥰🥰\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Assignment 5 nahi hai isme par\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Ye 5 hai\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Ok 👍 👌\n',
#  'Ayush Chamoli: ✨\n',
#  'Akshat Rai: Isme 3 prove nahi kiye\n',
#  'Ayush Chamoli: Nhi\n',
#  'Ayush Chamoli: Are mereko\n',
#  'Ayush Chamoli: Mene*\n',
#  'Ayush Chamoli: Knhi se chepa hai\n',
#  'Ayush Chamoli: Toh idk\n',
#  'Akshat Rai: Acha\n',
#  'Ayush Chamoli: Y\n',
#  'Ayush Chamoli: A\n',
#  'Ayush Chamoli: Are yehi likh le\n',
#  'Akshat Rai: Ok\n',
#  'Ayush Chamoli: Mam itna dekhengi nhi vese\n',
#  'Akshat Rai: Ok\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Notes bhi bhj de\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Index bhej dena Cs ka\n',
#  'Akshat Rai: Aur certificate , record me Jo likhna hai woh bhi\n',
#  'Ayush Chamoli: okay\n',
#  'Ayush Chamoli: Plane sheet pe krna hai\n',
#  'Ayush Chamoli: Ya ruled\n',
#  'Ayush Chamoli: ?\n',
#  'Akshat Rai: Plane a4 sheets\n',
#  'Ayush Chamoli: Abe\n',
#  'Ayush Chamoli: Yrr\n',
#  'Ayush Chamoli: Nrml bhi chl hi jayegi\n',
#  'Akshat Rai: Han\n',
#  'Ayush Chamoli: Ab plane knha se laau\n',
#  'Ayush Chamoli: Merepe ek side rule ek side plane toh hai\n',
#  'Akshat Rai: Kharid lo\n',
#  'Ayush Chamoli: Ya no option left\n',
#  'Akshat Rai: Index bhejdo\n',
#  'Akshat Rai: Cs ka\n',
#  'Akshat Rai: Record aur certificate me bhi kuch likhna hai\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Thank you\n',
#  'Ayush Chamoli: Bro listen\n',
#  'Ayush Chamoli: Mereko\n',
#  'Ayush Chamoli: Nortan vala experiment\n',
#  'Ayush Chamoli: Maximum power theorem ka graph\n',
#  'Ayush Chamoli: Aur last experiment bhi pura\n',
#  'Ayush Chamoli: Bhj de\n',
#  'Ayush Chamoli: Please\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Bhai\n',
#  'Ayush Chamoli: Vo bhj na\n',
#  'Ayush Chamoli: Array ka\n',
#  'Ayush Chamoli: Flowchart\n',
#  'Akshat Rai: Bhejta hun\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Kya krna hai inka??\n',
#  'Akshat Rai: Zarurat pad sakti hai\n',
#  'Ayush Chamoli: cheating ke liye\n',
#  'Akshat Rai: Han\n',
#  'Ayush Chamoli: cool cool cool cool coool\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Apne words me likh dena\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Mai toh rat ke gaya Tha pickling baar\n',
#  'Akshat Rai: Abhi to mijhe bhi yaad nahi\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: 11 baje tak wait Karo order toh same hi hona chaiye\n',
#  'Ayush Chamoli: yaa\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: 👍\n',
#  'Akshat Rai: Kaha bhejdiye recursion ke program\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Ye wale questions hi toh hai recursion hai\n',
#  'Ayush Chamoli: Ke*\n',
#  'Akshat Rai: Okk\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Okk\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Ek baar check bhi Kar lena\n',
#  'Ayush Chamoli: Thik hai\n',
#  'Ayush Chamoli: Thank you\n',
#  'Akshat Rai: Ok\n',
#  'Akshat Rai: bhai sir ke 1d array ke question bhejdo saare\n',
#  'Akshat Rai: Switch off aara hai uska phone\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Acha\n',
#  'Akshat Rai: Krishna ko phone karp\n',
#  'Akshat Rai: Karo\n',
#  'Akshat Rai: Index aur certificate ki photo bhejdena twrmwork ki\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Series vala\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Ohho\n',
#  'Ayush Chamoli: Itni\n',
#  'Ayush Chamoli: Aesthetic dp\n',
#  'Akshat Rai: Thanks\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Thank you bhai🫶🏻\n',
#  'Ayush Chamoli: https://qrco.de/bdjMFv\n',
#  'Ayush Chamoli: Ispe account bna de\n',
#  'Ayush Chamoli: Aur jis mail se bnayega\n',
#  'Ayush Chamoli: Vo bhj de\n',
#  'Akshat Rai: Hai kya ye ??\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Oye sun\n',
#  'Ayush Chamoli: Ek kaam krde plss plss\n',
#  'Akshat Rai: Kyaa ??\n',
#  'Ayush Chamoli: Subah 7 35 ya 7 40 pe na\n',
#  'Ayush Chamoli: Ek ldki milegi\n',
#  'Ayush Chamoli: Tujhe\n',
#  'Ayush Chamoli: Jnha cllg mein bus khadi hoti hai na\n',
#  'Ayush Chamoli: Vnha pe\n',
#  'Ayush Chamoli: Vo ek panni degi\n',
#  'Ayush Chamoli: Vo rkh liyo plss\n',
#  'Ayush Chamoli: Mein tujhse aake le lunga fir\n',
#  'Akshat Rai: Insta pe shellhead ke naam se request aai hogi ..\n',
#  'Ayush Chamoli: Dekhta hu\n',
#  'Akshat Rai: Happy Holi bhrata ..\n',
#  'Ayush Chamoli: Happy holi bhai\n',
#  'Ayush Chamoli: RESULT:\n\nThe given water sample contains following type of hardness: \nTotal Hardness: 470ppm\nPermanent Hardness:280ppm\nTemporary Hardness:190ppm\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Thanks\n',
#  'Akshat Rai: Yo\n',
#  'Akshat Rai: !!\n',
#  'Ayush Chamoli: Yo ho singh\n',
#  'Akshat Rai: Wassup\n',
#  'Akshat Rai: ??\n',
#  'Ayush Chamoli: Nothing you tell\n',
#  'Akshat Rai: Something good something bad or maybe worse\n',
#  'Ayush Chamoli: Mine is everything worse\n',
#  'Akshat Rai: Kyu kya hua ??\n',
#  'Ayush Chamoli: Aese hi\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Ye 8 hI\n',
#  'Ayush Chamoli: Hai*\n',
#  'Akshat Rai: 7 kaunsa hai fir\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Okl\n',
#  'Akshat Rai: Okk\n',
#  'Akshat Rai: Dp mein ye sexy banda kaun hain ..\n',
#  'Ayush Chamoli: Hahahaha\n',
#  "Ayush Chamoli: Dekhne mein toh Ranbir Kapoor lg rha hai baki I really don't know\n",
#  'Akshat Rai: Yeh jawaani hai deewani wala\n',
#  'Ayush Chamoli: Haaaaaannnn\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Question bhi bhejdo\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Akshat sun\n',
#  'Ayush Chamoli: Mein aur munjal Kal sakshi ko prank krenge\n',
#  'Ayush Chamoli: Ki humne kaam nhi kiya\n',
#  'Ayush Chamoli: Bol mat diyo uske samne glti se ki kr diya\n',
#  'Ayush Chamoli: Thik hai\n',
#  'Akshat Rai: Okk boss\n',
#  'Akshat Rai: Mera full sahyog hai\n',
#  'Ayush Chamoli: Thank you\n',
#  'Akshat Rai: Bhai algo bhej de\n',
#  'Ayush Chamoli: Mere paas khud nhi hai\n',
#  'Ayush Chamoli: Tujhe mile toh bhjiyo mujhe bhi\n',
#  'Akshat Rai: Arre ..\n',
#  'Akshat Rai: https://youtube.com/playlist?list=PLBlnK6fEyqRjMH3mWf6kwqiTbT798eAOm\n',
#  'Ayush Chamoli: Bhj na bhai\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Maths ke assignment ke answer hai kya\n',
#  'Akshat Rai: ??\n',
#  'Ayush Chamoli: Nhi\n',
#  'Ayush Chamoli: Yrr\n',
#  'Ayush Chamoli: Terepe aaye toh bhj diyo mujhe bhi\n',
#  'Akshat Rai: okk\n',
#  'Ayush Chamoli: Mila knhi se\n',
#  'Akshat Rai: nahi yaar\n',
#  'Ayush Chamoli: Ayush53\n',
#  'Ayush Chamoli: Deepikapadukone\n',
#  'Ayush Chamoli: Bhai krdiyo copy paste\n',
#  'Ayush Chamoli: Plsssss\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Hoga kya isse\n',
#  'Ayush Chamoli: ??\n',
#  'Ayush Chamoli: This message was deleted\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Pata nahi autocad hi nahi khul raha hai\n',
#  'Ayush Chamoli: Fir ab\n',
#  'Ayush Chamoli: ???\n',
#  'Ayush Chamoli: Copy paste kr diya tha\n',
#  'Akshat Rai: Kaise karu autocad hi nahi khul raha hai\n',
#  'Ayush Chamoli: Kisi ka bhi\n',
#  'Ayush Chamoli: Ya mera Mera sirf\n',
#  'Ayush Chamoli: Kisi\n',
#  'Ayush Chamoli: Dusre comp pe try maar\n',
#  'Akshat Rai: Are saare occupied han badi mushkil se ek mila tha\n',
#  'Akshat Rai: Vaise sir us din check nahi karenge\n',
#  'Akshat Rai: Sir ne aaj hi check kar liya sabka pc\n',
#  'Ayush Chamoli: Toh ab uss din nhi krengr na\n',
#  'Ayush Chamoli: Sure??\n',
#  'Akshat Rai: Haan\n',
#  'Akshat Rai: Sheet bhi nahi lani us din\n',
#  'Akshat Rai: Mana kiya hain\n',
#  'Ayush Chamoli: Thik hai\n',
#  'Ayush Chamoli: Oye humare sare ques\n',
#  'Ayush Chamoli: Points plane lines\n',
#  'Ayush Chamoli: Sbke ques\n',
#  'Ayush Chamoli: 1 quad mein hai na\n',
#  'Akshat Rai: points ke baaki quadrants me bhi hai\n',
#  'Akshat Rai: baaki planes aur lines 1st quadrant mein hain\n',
#  'Ayush Chamoli: Acha\n',
#  'Ayush Chamoli: Thik hai\n',
#  'Akshat Rai: points aur planes ke questions bhej do\n',
#  'Akshat Rai: jo sir ne karaye hain\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Oye ye\n',
#  'Ayush Chamoli: Kl knhi bhi Beth skte hain practical ke time pe ??\n',
#  'Akshat Rai: Haan\n',
#  'Ayush Chamoli: Pkka \nSir ne bola tha knhi bhi Beth jana\n',
#  'Akshat Rai: Haan\n',
#  'Ayush Chamoli: Okay\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Maine request bhejdi\n',
#  'Ayush Chamoli: Kisko\n',
#  'Akshat Rai: Jiske baare mein aaj baat ho rahi thi\n',
#  'Ayush Chamoli: Acha acha\n',
#  'Ayush Chamoli: Shi hai\n',
#  'Ayush Chamoli: Dono ko??\n',
#  'Akshat Rai: Dusri kaun hai\n',
#  'Akshat Rai: Akanksha\n',
#  'Ayush Chamoli: Ya\n',
#  'Akshat Rai: Baad me bhejta hun\n',
#  'Akshat Rai: Usse\n',
#  'Akshat Rai: Pehle accept karle ek dost\n',
#  'Akshat Rai: Aur nahi kiya toh ?? 😨😨\n',
#  'Ayush Chamoli: Are kregi kregi\n',
#  'Akshat Rai: Hopes alive\n',
#  "Ayush Chamoli: Don't be tensed\n",
#  'Ayush Chamoli: Agr vo smjh gyi\n',
#  'Ayush Chamoli: Ki tu vhi hai\n',
#  'Akshat Rai: Aapko request kab aayi thi\n',
#  'Ayush Chamoli: Toh ho jayegi\n',
#  'Akshat Rai: Achaa\n',
#  'Ayush Chamoli: Phele mansi ki aayi thi\n',
#  'Ayush Chamoli: Fir Kal prso mein\n',
#  'Ayush Chamoli: Akansha\n',
#  'Akshat Rai: Date puch raha hun ??\n',
#  'Ayush Chamoli: Ye thdi yaad Hota hai\n',
#  'Ayush Chamoli: Acha nhi\n',
#  'Ayush Chamoli: Mansi ko mene bhji thi\n',
#  'Akshat Rai: Achaa\n',
#  'Ayush Chamoli: Usne 5 10 min mein hi krdi thi\n',
#  'Akshat Rai: Okk\n',
#  'Ayush Chamoli: Aur fir\n',
#  'Ayush Chamoli: Akanksha ki jese hi aayi\n',
#  'Ayush Chamoli: 5 10 mein mene krdi thi\n',
#  'Akshat Rai: Achaa ..\n',
#  'Akshat Rai: Hogayi accept\n',
#  'Ayush Chamoli: Mubarkho\n',
#  'Akshat Rai: 🤩🤩🤩\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Cn ka ye hai\n',
#  'Ayush Chamoli: Ye galat hai\n',
#  'Akshat Rai: Acha matlab koi exception nahi hai\n',
#  'Ayush Chamoli: Hn\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Was it ok\n',
#  'Akshat Rai: ??\n',
#  'Ayush Chamoli: Ya it was okay\n',
#  'Ayush Chamoli: Kuch ajeeb nhi tha\n',
#  'Ayush Chamoli: But next time try\n',
#  'Ayush Chamoli: To say hi first\n',
#  'Ayush Chamoli: Then vo reply kre\n',
#  'Ayush Chamoli: Then talk ahead\n',
#  'Akshat Rai: acha ..\n',
#  'Akshat Rai: experiment ki reading bhejdo chemistry ke last wale ki\n',
#  'Ayush Chamoli: Mein toh doiwala hu\n',
#  'Ayush Chamoli: File toh nhi hai yrr merepe\n',
#  'Akshat Rai: toh fir usi se mangu kya\n',
#  'Ayush Chamoli: Haan maang le\n',
#  'Ayush Chamoli: Try it with\n',
#  'Akshat Rai: okk\n',
#  'Ayush Chamoli: Mansi???\n',
#  'Ayush Chamoli: FIR VO BOLEGI HAAN THEN GO WITH IT\n',
#  'Akshat Rai: thanks ..\n',
#  'Ayush Chamoli: Isme thanks kya\n',
#  'Ayush Chamoli: Isse thdi ptegu\n',
#  'Ayush Chamoli: Ptegi\n',
#  'Ayush Chamoli: 😂😂😂\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: You awake??\n',
#  'Akshat Rai: Yes\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Edit krke bhj de\n',
#  'Ayush Chamoli: Ho nhi rhe ye\n',
#  'Akshat Rai: Are edit pdf mein jakar naam likhdena\n',
#  'Akshat Rai: I love pdf par jake\n',
#  'Ayush Chamoli: Bht jyada\n',
#  'Ayush Chamoli: Alg dikh rha hai vo\n',
#  'Ayush Chamoli: Smjh aa rha hai Pura ki chepa hua hai\n',
#  'Akshat Rai: Mera dekhna ek baar agar ye sahi hai to aise hi kardunga\n',
#  'Ayush Chamoli: Bhj\n',
#  'Akshat Rai: 1 min\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: bhai\n',
#  'Ayush Chamoli: mera bhi krde\n',
#  'Akshat Rai: Sahi hai kya\n',
#  'Ayush Chamoli: Haan shi hai\n',
#  'Ayush Chamoli: Sakshi ka bhi kr diyo\n',
#  'Ayush Chamoli: Plss\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: sahi hai ..\n',
#  'Akshat Rai: sakshi ke surname ki spelling sarswat hai kya\n',
#  'Ayush Chamoli: Haan\n',
#  'Ayush Chamoli: Thank you bhai🫶🏻\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: https://www.ques10.com/p/66547/find-a-fourier-series-to-represent-x-x2-from-x-p-1/\n',
#  'Akshat Rai: Aara hun\n',
#  'Ayush Chamoli: Bhai jldi\n',
#  'Akshat Rai: https://youtu.be/E3gooO-4tPc\n',
#  'Ayush Chamoli: Thanks bhai🚩\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Electronics kaha se padhoge\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Dekhna pdega\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: #include<stdio.h>\n#include<string.h>\nint main(){\n    FILE *fp,*fp1;\n    int n,number;\n    fp=fopen("input.txt","w");\n    printf("enter the limit");\n    scanf("%d",&n);\n\n    for(int i=0;i<n;i++){\n        scanf("%d",&number);\n        putw(number,fp);\n    }\n    fclose(fp);\n    fp=fopen("input.txt","r");\n    fp1=fopen("single.txt","w");\n    int rem;\n\n    while((number=getw(fp))!=EOF){\n        if(number>=0 && number<=9){\n            putw(number,fp1);\n        }\n        else {\n            int total=0;\n            while(number!=0){\n                rem=number%10;\n                total=(total*10)+rem;\n                number=number/10;\n                \n\n            }\n            putw(total,fp1);\n        }\n    }\n\n    fclose(fp);\n    fclose(fp1);\n\n    fp1=fopen("single.txt","r");\n    while((number=getw(fp1))!=EOF){\n        printf("%d\\t",number);\n    }\n    fclose(fp1);\n}\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Iska 2 hua?\n',
#  'Akshat Rai: Abhi kara nahi karta hun\n',
#  'Ayush Chamoli: Plss\n',
#  'Ayush Chamoli: Krke dedo\n',
#  'Akshat Rai: Karta hun abhi dusra kar raha tha\n',
#  'Akshat Rai: #include<stdio.h>\nvoid main()\n{\n    FILE *fp,*fpp,*fpn;\n    int n,i,x,tmp,c;\n    fp=fopen("abc.txt","w+");\n    fpp=fopen("prime.txt","w+");\n    fpn=fopen("nonprime.txt","w+");\n    printf("Enter limit :");\n    scanf("%d",&n);\n    for(i=0;i<n;i++)\n    {\n        scanf("%d",&x);\n        putw(x,fp);\n    }\n    rewind(fp);\n    while((tmp=getw(fp))!=EOF)\n    {\n        c=0;\n        for(i=1;i<=tmp;i++)\n        {\n            if(tmp%i==0)\n            {\n                c++;\n            }\n        }\n        if(c==2)\n        {\n            putw(tmp,fpp);\n        }\n        else\n        {\n            putw(tmp,fpn);\n        }\n    }\n    rewind(fp);\n    rewind(fpp);\n    rewind(fpn);\n    printf("Contents of \\"prime.txt\\":-\\n");\n    while((n=getw(fpp))!=EOF)\n    {\n        printf("%d ",n);\n    }\n    printf("\\nContents of \\"nonprime.txt\\":-\\n");\n    while((n=getw(fpn))!=EOF)\n    {\n        printf("%d ",n);\n    }\n    fclose(fp);\n    fclose(fpp);\n    fclose(fpn);\n}\n',
#  'Akshat Rai: upper case wala question hua kya\n',
#  'Ayush Chamoli: Knsa\n',
#  'Ayush Chamoli: Toggle vala\n',
#  'Ayush Chamoli: ?\n',
#  'Akshat Rai: Ye wala\n',
#  'Ayush Chamoli: Haan\n',
#  'Akshat Rai: Code bhejdo\n',
#  'Ayush Chamoli: #include <stdio.h>\n\nvoid cap(char *);\n\nint main()\n{\n    char str[100];\n    printf("input the string:\\n");\n    gets(str);\n    cap(str);\n\n    return 0;\n}\nvoid cap(char *p)\n{\n    int i;\n    for(i=0;*(p+i)!=\'\\0\';i++)\n    {\n        if(i==0||(*(p+i-1)==\' \'))\n        {\n            if((*(p+i)>=\'A\')&& (*(p+i)<=\'Z\'))\n            {\n                while(*(p+i)!=\' \')\n                {\n                    printf("%c",*(p+i));\n                    i++;\n                }\n            }\n        }\n    }\n}\n',
#  'Ayush Chamoli: #include <stdio.h>\n\nint main()\n{\n    char tmp;\n    int i;\n    \n    FILE* fp;\n    fp = fopen("fukra.txt", "w+");\n    \n    while ((tmp = getchar()) != EOF)\n    {\n        putc(tmp, fp);\n    }\n    \n    do\n    {\n        fseek(fp, -1, 1);\n        putchar(getc(fp));\n        fseek(fp, -1, 1);\n    }\n    while (ftell(fp)>0);\n    \n    fclose(fp);\n    \n    return 0;\n}\n',
#  'Ayush Chamoli: Ye pkka shi hai na\n',
#  'Akshat Rai: Haan\n',
#  'Ayush Chamoli: Reverse ke liye ?\n',
#  'Akshat Rai: #include<stdio.h>\nint fact(int);\nvoid main()\n{\n    FILE *fp,*ff;\n    int n,i,tmp;\n    fp=fopen("input.txt","w+");\n    ff=fopen("fact.txt","w+");\n    printf("Enter Limit");\n    scanf("%d",&n);\n    for(i=0;i<n;i++)\n    {\n        scanf("%d",&tmp);\n        putw(tmp,fp);\n    }\n    rewind(fp);\n    while((tmp=getw(fp))!=EOF)\n    {\n        putw(fact(tmp),ff);\n    }\n    rewind(ff);\n    while((tmp=getw(ff))!=EOF)\n    {\n        printf("%d\\t",tmp);\n    }\n}\nint fact(int n)\n{\n    int i=1,fact=1;\n    for(i=1;i<=n;i++)\n    {\n        fact=fact*i;\n    }\n    return fact;\n}\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Ye space se pkka ho jayega\n',
#  'Ayush Chamoli: ?\n',
#  'Akshat Rai: Haan\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Iska puch rhi hai\n',
#  'Ayush Chamoli: Bta de plss\n',
#  'Akshat Rai: Initialize 1 se karna\n',
#  'Akshat Rai: Print counter as it is hoga\n',
#  'Akshat Rai: Word wala\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Haan\n',
#  'Akshat Rai: Hamn 1 se initìize 1 se kiya hai\n',
#  'Akshat Rai: Toh +1 karne ki zarurat nahi hai\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Haan\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: 0 se\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Video bhejdo transistor ki saari\n',
#  'Ayush Chamoli: Kya rha result?\n',
#  'Akshat Rai: Theek  theek tha\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Kitna bna total?\n',
#  'Akshat Rai: Guess karo ??\n',
#  'Ayush Chamoli: Tu bta\n',
#  'Akshat Rai: Ye video itni hi hai kya\n',
#  'Ayush Chamoli: Hnn\n',
#  'Akshat Rai: 95\n',
#  'Akshat Rai: Aapka\n',
#  'Ayush Chamoli: Transistor ki yhi hai\n',
#  'Akshat Rai: Kitna aaya\n',
#  'Ayush Chamoli: 102\n',
#  'Ayush Chamoli: Pr computer mein bekar hai\n',
#  'Ayush Chamoli: 17 hi hain\n',
#  'Akshat Rai: Mere bhi itne hi hai\n',
#  'Ayush Chamoli: Haan\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Yr kya hai\n',
#  'Ayush Chamoli: Abhi aaye\n',
#  'Ayush Chamoli: 11 2 pe\n',
#  'Akshat Rai: okkk sorry\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Bhai\n',
#  'Ayush Chamoli: Comp ke notes bhj de\n',
#  'Akshat Rai: bhai mere paas jaise hi aayega mai bhejdunga\n',
#  'Ayush Chamoli: Kb tkk ayenge???\n',
#  'Akshat Rai: Pata nahi bhai\n',
#  'Ayush Chamoli: Okay bhaaaiii\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Thanks\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: l=int(input("Enter range left"))\nr=int(input("Enter range right"))\nfor i in range(l,r+1):\n    if(i%2==0):\n        print("Lucky Number")\n    elif(i%3==0):\n        print("Lucky Number")\n    elif(i%9==0):\n        print("Lucky Number")\n    else:\n        print("Not Lucky Number")\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Ye questions krne hai kya??\n',
#  'Akshat Rai: Nahi\n',
#  'Ayush Chamoli: Sure bhai??\n',
#  'Akshat Rai: Sirf jo sir ne karaye hai vaise hi aate hai\n',
#  'Akshat Rai: 💯\n',
#  'Ayush Chamoli: Okay bhaj\n',
#  'Ayush Chamoli: 💪🏻\n',
#  'Akshat Rai: Electro mein fuel cells aur corrosion aayega kya\n',
#  'Ayush Chamoli: Pta ni yrrr\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Ismein sab hai maine bhi isi se padha hain\n',
#  'Ayush Chamoli: Kuch bcha\n',
#  'Ayush Chamoli: Jo nhi hai???\n',
#  'Ayush Chamoli: Iss pdf mein\n',
#  'Akshat Rai: Nahi\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Ye rahta hai bas\n',
#  'Ayush Chamoli: Okay\n',
#  'Ayush Chamoli: Thanks bhai\n',
#  'Ayush Chamoli: 💪🏻\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: bhai yrr applications bhi bhj do plss\n',
#  'Akshat Rai: Ye applications nahi ye alag topic hai\n',
#  'Ayush Chamoli: Bhj de\n',
#  'Akshat Rai: Acha\n',
#  'Ayush Chamoli: Fir kya hai vi topic\n',
#  'Ayush Chamoli: Vo*\n',
#  'Ayush Chamoli: Kya pta kaam ka ho\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Ye toh bht Sara hai bhai\n',
#  'Ayush Chamoli: Shit\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Mujhe paper bhej do who pichle sem wala\n',
#  'Akshat Rai: jo aapke paas hai\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Ye 1 page hi hai bs mere paas\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Happy Birthday Bhai 🎂\n',
#  'Akshat Rai: Sorry , thoda late hogaya honestly speaking mujhe yaad nahi woh ghar par hun toh itna insta bhi nahi dekh raha bas abhi abhi ayush aur sakshi ki story dekhi\n',
#  'Ayush Chamoli: Thank you bhai❤️🫶🏻\n',
#  "Ayush Chamoli: Arey it's fine bhai❤️❤️\n",
#  'Akshat Rai: Kaunsa section mila\n',
#  'Akshat Rai: ??\n',
#  'Ayush Chamoli: Iot\n',
#  'Akshat Rai: Achaa\n',
#  'Ayush Chamoli: Tera\n',
#  'Akshat Rai: DS1\n',
#  'Ayush Chamoli: Shi hai\n',
#  'Ayush Chamoli: Cllg kbse jaaoge?\n',
#  'Akshat Rai: Monday  31\n',
#  'Ayush Chamoli: Same\n',
#  'Ayush Chamoli: Kya rha bhai\n',
#  'Ayush Chamoli: ?\n',
#  'Akshat Rai: Matlab\n',
#  'Akshat Rai: ..\n',
#  'Ayush Chamoli: Result\n',
#  'Akshat Rai: Achaa dekhta hun\n',
#  'Ayush Chamoli: Hm\n',
#  'Akshat Rai: 9.23\n',
#  'Akshat Rai: Aapki ???\n',
#  'Ayush Chamoli: Nice bhai\n',
#  'Ayush Chamoli: 🥳🥳\n',
#  'Ayush Chamoli: 9.3\n',
#  'Akshat Rai: Arre Thanks 😊\n',
#  'Akshat Rai: Great\n',
#  'Akshat Rai: Congo\n',
#  'Ayush Chamoli: 💪🏻🙏🏻\n',
#  'Ayush Chamoli: Missed voice call\n',
#  'Ayush Chamoli: Bhai\n',
#  'Ayush Chamoli: Call kro\n',
#  'Ayush Chamoli: Mera recharge Khatam hogya hai\n',
#  'Ayush Chamoli: Merse call nhi jayega\n',
#  'Ayush Chamoli: Tu kr\n',
#  'Ayush Chamoli: Bhai\n',
#  'Ayush Chamoli: Bhj na aswal vale questions\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Tumhara 1 ch start kra diya??\n',
#  'Akshat Rai: Nahi\n',
#  'Akshat Rai: Kuch videos vagera malum hai kya\n',
#  'Akshat Rai: Padhne ke liye\n',
#  'Ayush Chamoli: Fir ye basis linearly dependent vgerah kya hai\n',
#  'Ayush Chamoli: Ye toh 1 ch ka hai\n',
#  'Ayush Chamoli: Mene alg alg video se pda tha\n',
#  'Ayush Chamoli: Kuch gajender\n',
#  'Ayush Chamoli: Kuch koi bhagwan das\n',
#  'Akshat Rai: Bhej do\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: Bhaaaaaaaaiiiiii\n',
#  'Ayush Chamoli: Yrr\n',
#  'Ayush Chamoli: Mereko uss assignment ke jitney krlega\n',
#  'Ayush Chamoli: Unke solution bhj de\n',
#  'Ayush Chamoli: Plessis\n',
#  'Ayush Chamoli: Jese bhi ho\n',
#  'Ayush Chamoli: Bhj de\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Thank you🫱🏻\u200d🫲🏻👏🏻🫶🏻👍🏻🙏🏻🥂\n',
#  'Akshat Rai: ..\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: 1st chapter ke assignment ke solutions\n',
#  'Akshat Rai: Jitne bhi hai bhej do\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Thanks 😇\n',
#  "Ayush Chamoli: You're welcome\n",
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: +1\n',
#  'Ayush Chamoli: +1\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Is wale formula me galti hai\n',
#  'Akshat Rai: Ye sahi hai completely\n',
#  'Ayush Chamoli: Okay bhai\n',
#  'Akshat Rai: Link bhejdo\n',
#  'Akshat Rai: Jay code ka\n',
#  'Ayush Chamoli: Abe\n',
#  'Ayush Chamoli: Vo mere mein hi nhi khulra ab\n',
#  'Ayush Chamoli: Shyd 1 person vala krdiya\n',
#  'Ayush Chamoli: Ab mene sir ko mail dala hua hai\n',
#  'Ayush Chamoli: Kholne ke liye\n',
#  'Akshat Rai: Ok\n',
#  'Akshat Rai: Mera khul gaya\n',
#  'Ayush Chamoli: Kya dala\n',
#  "Ayush Chamoli: I'd password\n",
#  'Akshat Rai: Register kiya tha\n',
#  'Akshat Rai: Fir mail aayi aur account activate kar liya\n',
#  'Ayush Chamoli: Okay\n',
#  'Ayush Chamoli: Nice\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: #include<stdio.h>\n#include<stdlib.h>\ntypedef struct poly\n{\n    int ex,co;\n    struct poly *next;\n}poly;\npoly *create();\nvoid display(poly *);\npoly *add(poly*,poly*);\nint main()\n{\n    poly *p1=NULL,*p2=NULL,*p3=NULL;\n    p1=create();\n    printf("1st polynomial is");\n    display(p1);\n    p2=create();\n    printf("2nd is");\n    display(p2);\n    p3=add(p1,p2);\n    printf("1st \\npolynomial is\\n");\n    display(p1);\n    printf("2nd \\npolynomial is\\n");\n    display(p2);\n    \n    printf("\\nafter adding \\n");\n    display(p3);\n    return 0;\n}\npoly *create()\n{\n    int ex,co,ch;\n    poly *l=NULL,*r=NULL,*p=NULL;\n    while(1)\n    {\n        printf("\\nenter the coefficent");\n        scanf("%d",&co);\n        printf("enter the expo");\n        scanf("%d",&ex);\n        p=(poly*)malloc(sizeof(poly));\n        p->ex=ex;\n        p->co=co;\n        if(r==NULL&&l==NULL)\n        {\n            r=l=p;\n            r->next=NULL;\n            l->next=NULL;\n        }\n        else\n        {\n            r->next=p;\n            r=p;\n        }\n        r->next=NULL;\n        \n        \n        printf("do you want to continue");\n        scanf("%d",&ch);\n        if(ch==0)\n            break;\n        \n        \n    }\n    return l;\n    \n}\nvoid display(poly *h)\n{\n    while(h!=NULL)\n    {\n        printf("+%d(x)^%d",h->co,h->ex);\n        h=h->next;\n    }\n}\npoly *add(poly*h1,poly*h2)\n{\n    poly*p=NULL,*r=NULL,*l=NULL;\n    while(h1!=NULL&&h2!=NULL)\n    {\n        p=(poly*)malloc(sizeof(poly));\n        if(h1->ex==h2->ex)\n        {\n            p->ex=h1->ex;\n            p->co=(h1->co+h2->co);\n            h1=h1->next;\n            h2=h2->next;\n    }\n    else if(h1->ex>h2->ex)\n    {\n        p->ex=h1->ex;\n        p->co=h1->co;\n        h1=h1->next;\n        \n        \n    }\n    else{\n        p->ex=h2->ex;\n        p->co=h2->co;\n        h2=h2->next;\n    }\n    if(r==NULL&&l==NULL)\n        {\n            r=l=p;\n            r->next=NULL;\n            l->next=NULL;\n        }\n        else\n        {\n            r->next=p;\n            r=p;\n        }\n        r->next=NULL;\n}\nwhile(h1!=NULL)\n{\n    p=(poly*)malloc(sizeof(poly));\n    p->ex=h1->ex;\n    p->co=h1->co;\n    r->next=p;\n    r=p;\n    h1=h1->next;\n    \n}\nwhile(h2!=NULL)\n{\n     p=(poly*)malloc(sizeof(poly));\n    p->ex=h2->ex;\n    p->co=h2->co;\n    r->next=p;\n    r=p;\n    h2=h2->next;\n}\nreturn l;\n}\n',
#  'Ayush Chamoli: Bhai\n',
#  'Ayush Chamoli: Kua ques aaye\n',
#  'Ayush Chamoli: Kya*\n',
#  'Ayush Chamoli: Mar gya kya???\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: null\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Duhh yes!\n',
#  'Akshat Rai: Dahej mein kya mil raha hai ??\n',
#  'Ayush Chamoli: Ladki ka bhai\n',
#  'Akshat Rai: Shit yaar , mujhe laga tha fortuner mile gi\n',
#  'Ayush Chamoli: Heh3\n',
#  'Ayush Chamoli: Courses knse krne hain\n',
#  'Ayush Chamoli: Cllg ke according?\n',
#  'Akshat Rai: Matlab\n',
#  'Ayush Chamoli: Are vo swyam aur coursera ke jo the\n',
#  'Ayush Chamoli: Unme se\n',
#  'Akshat Rai: Swayam toh nahi pata\n',
#  'Akshat Rai: Coursera ke saare karne hai matlab 3\n',
#  'Ayush Chamoli: Iss sem mein hi??\n',
#  'Akshat Rai: Haan\n',
#  'Ayush Chamoli: Merepe 4 hain?\n',
#  'Akshat Rai: Haan toh charo\n',
#  'Ayush Chamoli: Abe\n',
#  'Ayush Chamoli: Pr ye sem toh nikl gya\n',
#  'Akshat Rai: Haan yaar\n',
#  'Akshat Rai: Main bhi nahi kar paunga\n',
#  'Ayush Chamoli: Fir??\n',
#  'Akshat Rai: So jaate hain\n',
#  'Ayush Chamoli: Nice idea\n',
#  'Ayush Chamoli: Class\n',
#  'Akshat Rai: Kitna time lagega\n',
#  'Ayush Chamoli: 10 15 min\n',
#  'Ayush Chamoli: Ab hone vali hai attendance start\n',
#  'Akshat Rai: <Media omitted>\n',
#  "Ayush Chamoli: What about them [ we ] who don't have dandiya??\n",
#  'Akshat Rai: Waha milti hai\n',
#  'Ayush Chamoli: Cools\n',
#  'Akshat Rai: 4 baje se pehle shuru hoga toh 3 30 baje chalenge\n',
#  'Ayush Chamoli: ok bhai ji\n',
#  'Ayush Chamoli: Happy Diwali bhai ❤️\n',
#  'Akshat Rai: Happy Diwali 🫂\nBtw I have something for you\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Haha😂😂😂\n',
#  'Akshat Rai: Dehradun kab aa rahe ho ??\n',
#  'Ayush Chamoli: Sunday\n',
#  'Akshat Rai: Nice\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Roll No 14\n',
#  'Akshat Rai: Please baat kar lena\n',
#  "Ayush Chamoli: I'll try\n",
#  'Akshat Rai: null\n',
#  'Akshat Rai: null\n',
#  'Akshat Rai: kal 7:30 baje phone utha lena\n',
#  'Ayush Chamoli: Okay bhai\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: hello\n',
#  'Ayush Chamoli: hi bhai\n',
#  'Akshat Rai: Bhai speaker chahiye  tha ek din ke liye\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Sorry ye bhul gaya tha\n',
#  'Ayush Chamoli: Lelo\n',
#  'Ayush Chamoli: Kb chahiye\n',
#  'Akshat Rai: Monday ko le jana\n',
#  'Akshat Rai: Hai\n',
#  'Ayush Chamoli: Sakshi pe tha\n',
#  'Ayush Chamoli: Maang Lena usse\n',
#  'Akshat Rai: Okk\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: null\n',
#  'Ayush Chamoli: null\n',
#  'Akshat Rai: null\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: Bhai project\n',
#  'Akshat Rai: 10 30 pe karte hai na\n',
#  'Ayush Chamoli: Okay bhai\n',
#  'Ayush Chamoli: No pressure\n',
#  'Ayush Chamoli: Sorry agr lga ho ki mein pressurize kr rha hu\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Akshat Rai: Arre kaisi baat kar rahe ho\n',
#  'Akshat Rai: Agar pressurize karoge bhi then also\n',
#  'Akshat Rai: It is ok\n',
#  'Akshat Rai: I know you will\n',
#  'Akshat Rai: always think good for me\n',
#  'Ayush Chamoli: Aww\n',
#  'Ayush Chamoli: Yk na ki your message can make someone cry also\n',
#  'Akshat Rai: Arre 😂\n',
#  'Akshat Rai: Vaise how is my profile picture\n',
#  'Ayush Chamoli: Nice bhai🫶🏻\n',
#  'Akshat Rai: Thnx\n',
#  'Ayush Chamoli: Bhai call??\n',
#  'Akshat Rai: https://meet.google.com/auj-bsva-kai\n',
#  'Ayush Chamoli: Sbko bhj diya\n',
#  'Akshat Rai: haan\n',
#  'Ayush Chamoli: null\n',
#  'Ayush Chamoli: Bhjdo bhai\n',
#  'Akshat Rai: https://www.computervision.zone/courses/face-recognition-with-real-time-database/\n',
#  'Ayush Chamoli: null\n',
#  "Ayush Chamoli: You might be going through something and I am sorry in advance if I offend you but sometimes it's fine to vent it out to your people\n",
#  'Ayush Chamoli: And if I consider you as my confidant and someone to whom I can share my problems\n',
#  "Ayush Chamoli: It's quite bad to see you don't consider us that worthy\n",
#  'Ayush Chamoli: Baki whatever you feels right\n',
#  'Ayush Chamoli: bhaaaaaiiiiiiiiiiiiiiiiiiiiiiiiiiiii\n',
#  'Ayush Chamoli: bhjjjjjjooooooooooooooooooooooooooooo\n',
#  'Akshat Rai: sending...\n',
#  'Ayush Chamoli: projectttttttttttttttttttttttttttttttttt!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Ayush Chamoli: how to even run all this?\n',
#  'Akshat Rai: Images folder ☝🏻\n',
#  'Akshat Rai: You deleted this message\n',
#  'Ayush Chamoli: how to run all this?\n',
#  'Akshat Rai: Uske liye video ke 10 min dekh lena\n',
#  'Ayush Chamoli: shuru ki?\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: In resources folder ☝🏻\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Make one more folder in resources call modes and paste these images there ☝🏻\n',
#  'Ayush Chamoli: can i call you?\n',
#  'Ayush Chamoli: iske liye please\n',
#  'Akshat Rai: <Media omitted>\n',
#  'Akshat Rai: Arre yaar mai abhi term work ka kaam kar raha hun varna baat kar leta mujhe 30 ko submit karna hai C++ ka\n',
#  'Ayush Chamoli: ye encoding toh khul hi nhi rhi\n',
#  'Ayush Chamoli: kal ka pura din hai\n',
#  'Ayush Chamoli: plssssssssss\n',
#  'Akshat Rai: khulti ti nahi hai yeh ye sirf read hoti hai file mein\n',
#  'Akshat Rai: kar lena fir vaise video ke 10 min se ho jayega\n',
#  'Ayush Chamoli: oye\n',
#  'Ayush Chamoli: ye banana knha pe hai\n',
#  'Ayush Chamoli: pycharm pe????\n',
#  'Akshat Rai: vs code mein\n',
#  'Akshat Rai: use pip install to install a module\n',
#  'Ayush Chamoli: isne toh pycharm pe banaya hai\n',
#  'Akshat Rai: in terminal\n',
#  'Akshat Rai: farak nahi padta\n',
#  'Ayush Chamoli: oh okay okay\n',
#  'Ayush Chamoli: Ye firebase account bhi banana Hai kya??\n',
#  'Akshat Rai: Haan\n',
#  'Ayush Chamoli: Okay\n',
#  'Ayush Chamoli: Bro yrr\n',
#  'Ayush Chamoli: Ye toh ho hi nhi rha\n',
#  'Ayush Chamoli: Dimag kharab hogya mera\n',
#  'Ayush Chamoli: bhai\n',
#  'Ayush Chamoli: ye firebase ne dimag stkadiya hai mera\n',
#  'Ayush Chamoli: ab\n',
#  'Akshat Rai: Sorry yaar agar meri kisi baat se bura laga ho to 😔\n',
#  'Ayush Chamoli: Are nhi\n',
#  'Ayush Chamoli: Aesa toh kuch hua hi nhi😂\n',
#  "Ayush Chamoli: It's fien\n",
#  'Ayush Chamoli: Fine\n',
#  'Akshat Rai: Pakka na\n',
#  'Ayush Chamoli: Ha ha\n',
#  'Ayush Chamoli: Chill maar\n',
#  'Ayush Chamoli: "type": "service_account",\n  "project_id": "facerec-563f2",\n  "private_key_id": "1015e1398d00b8445cfbc983c73272edad8caf7a",\n  "private_key": "-----BEGIN PRIVATE KEY-----\\nMIIEvAIBADANBgkqhkiG9w0BAQEFAASCBKYwggSiAgEAAoIBAQCgZTrb+XbEcegR\\n/sOvB/YKiXLzRi+RaEaoKSILryeksolS6f5UoXoEe2MJzBq4bmDSIUnGZc+2MVOk\\n5U6S8wuEtnDUnkkJLRKk0/JbtovuHWJL+DDmgcLZbD99YFOOETQsa+Efq9NL8Cfa\\ngsvccCcOLAx/YL34KmFk+rX11D2Hzgc9Fb4rZf8PO2ls0H2ihU0XhkAWYDYxSrcY\\nnc8kP447vP1+BNyQzycqUJ0rUminMHrWuvtOHRw+rFDQ0B7hb+HNjsx5213nQtFb\\nVGggYWOH4NnORyeEY5p97cyRuajHEY+d4CgMqbSwrliIYqh2HhnsD5IDjWzqpemB\\npfChlQPtAgMBAAECggEABABihohjuSTqWECV2zEEp2CkeINAvozublWQXuBAyfAW\\nUvY5fR0GMURuxRjNddpzGerwrz1tACuc3ZlG642atPXkPLmyMsNoGqqa+kTEmu0q\\nvaB0f9uu48O6lcMocnvlZFJQrHyZ6eQU6nOm6Fn373eT3D2qn51XDrDeh0KDQncM\\nNV8aMPilWoQYiIubkAMDBBE8D8NfK7TCDVh5bqZtbxJpiiDQZ6DC9IjwJjwc4B7e\\nLq0IFazjlDSYdErnLZYmN2Bq+OH8nbqkJJJA9gCdd9tkjSE4zuKH6SfgSxFTiC/g\\nYbAVWm7tt31eJkrwspYZYMaDBq38rwnDf9tPDuFLYQKBgQDiBjuUiapMo66lX5S6\\nXnxykZOhqsAepBl57uVtTcixywCXK788WpU/9nCXc8GRdSp4HC1EYEJPU11qepy1\\n6MLsM1TE59599POutDRoilftkSJaMMqDC/otkAz4wLJTPHQo1Xqrcb3MngMGZ3ld\\nr97FOSuIGDzcFX0Gj7AcIfq4SQKBgQC1qtNXfyfW4HDjRCtONRHuPUH7bR+N6PTW\\nvyq3dvm+nOoGGYlW3ZQn0lh6VprYGSsSTRL/UAgCxCMcr4yVhMJI0WX49jPBJU/w\\nM9LhU7cvbmOfAUK4LpyoUfaFYZtcMZ3IPZkmaHXTVuwzBfdipd5CjkT9XPxtmW9C\\n1BWgzJUWhQKBgGtIMBGCAm5cJvJh2tNXM9ShmqRaytQAagNBTG7EQ+V4CLC4WA4K\\npNr2W1zX2eHz7hOStD3HPtIuLKH0zttdPuAkQTExKZ85nEypRlL0j2W4xMhwbj8j\\neT0VKcMMm9f8Utpq8c3csA0mVyM8DBRW/PM5/pqbfo+sN2rc2uePjVTZAoGANChX\\nhUd8qLTHtHhd9pZGD6CG0SkDZjr8EKvSF9qQ2akzh4zNYaM8ZjJ+NKGo02Jme1ql\\nmafgpOqrKhE8y7DSFxYHsPL+6PVNfili4k6myXdoIr656Sd40tq1bJYZhN657kPB\\nNMXJDmRmbD/KRwhYR8ORCy0nTFBBIW7Cxuf15gECgYB46XMWT/NjFYma+aoLbiA2\\nE7fQJGgBGsSernyFRPyOrTL8NIC9EHQ5EwfIEiM3Fs3a+ibUw9T9yqCkCr1uVfHJ\\nvCUFw44PQARmNx3nGCaoasKZnj8K+J2yJ6WXx8nhgCXHSclJSwnb18gUICNhuaL1\\nDEP9MPB5SvsyrXnQwod/Ww==\\n-----END PRIVATE KEY-----\\n",\n  "client_email": "firebase-adminsdk-qpsn8@facerec-563f2.iam.gserviceaccount.com",\n  "client_id": "102943930993785254767",\n  "auth_uri": "https://accounts.google.com/o/oauth2/auth",\n  "token_uri": "https://oauth2.googleapis.com/token",\n  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",\n  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/firebase-adminsdk-qpsn8%40facerec-563f2.iam.gserviceaccount.com",\n  "universe_domain": "googleapis.com"\n}\n',
#  'Ayush Chamoli: <Media omitted>\n',
#  'Ayush Chamoli: 1\n#include<iostream>\nusing namespace std;\nint main(){\n    string name;\n    cout<<"Enter user name:";\n    getline(cin,name);\n    int units;\n    double charge=50;\n    cout<<"Enter units:";\n    cin>>units;\n    if(units<=100)\n    {\n        charge+=units*.60;\n    }\n    else if(units>100&&units<=300)\n    {\n        charge+=60+(units-100)*.80;\n    }\n    else if(units>300)\n    {\n        charge+=60+160+(units-300)*.90;\n        charge=charge+.15*charge;\n    }\n    else\n    {\n        cout<<"invalid input!"<<endl;\n    }\n    cout<<"charge="<<charge<<endl;\n}\n',
#  ...]

# %%
dates=re.findall(pattern,data)
dates
# Out:
# ['01/12/22, 22:00 - ',
#  '01/12/22, 22:00 - ',
#  '01/12/22, 22:01 - ',
#  '01/12/22, 22:01 - ',
#  '01/12/22, 22:01 - ',
#  '01/12/22, 22:01 - ',
#  '02/12/22, 23:53 - ',
#  '08/12/22, 12:14 - ',
#  '08/12/22, 12:14 - ',
#  '08/12/22, 12:14 - ',
#  '08/12/22, 12:14 - ',
#  '08/12/22, 12:14 - ',
#  '08/12/22, 12
df.head()
# Out:
#                                             Messages               Dates
# 0  Messages and calls are end-to-end encrypted. N... 2022-12-01 22:00:00
# 1                   Ayush Chamoli: <Media omitted>\n 2022-12-01 22:00:00
# 2                               Akshat Rai: Thanks\n 2022-12-01 22:01:00
# 3                        Ayush Chamoli: Sorry bhai\n 2022-12-01 22:01:00
# 4                           Akshat Rai: No problem\n 2022-12-01 22:01:00

# %%
df.shape
# Out:
# (2635, 2)

# %%
users=[]
messages=[]
for message in df["Messages"]:
    entry=re.split("([\w\W]+?):\s",message)
    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[2])
    else:
        users.append("Group Notification")
        messages.append(entry[0])

df["Users"]=users
df["Message"]=messages
df.drop(columns=["Messages"],inplace=True)
df.head()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\aksha\AppData\Local\Temp\ipykernel_9968\2263969086.py:4: SyntaxWarning: invalid escape sequence '\w'
#   entry=re.split("([\w\W]+?):\s",message)
#                 Dates               Users  \
# 0 2022-12-01 22:00:00  Group Notification
# 1 2022-12-01 22:00:00       Ayush Chamoli
# 2 2022-12-01 22:01:00          Akshat Rai
# 3 2022-12-01 22:01:00       Ayush Chamoli
# 4 2022-12-01 22:01:00          Akshat Rai
#
#                                              Message
# 0  Messages and calls are end-to-end encrypted. N...
# 1                                  <Media omitted>\n
# 2                                           Thanks\n
# 3                                       Sorry bhai\n
# 4                                       No problem\n

# %%
df["Year"]=df["Dates"].dt.year

# %%
df.head()
# Out:
#                 Dates               Users  \
# 0 2022-12-01 22:00:00  Group Notification
# 1 2022-12-01 22:00:00       Ayush Chamoli
# 2 2022-12-01 22:01:00          Akshat Rai
# 3 2022-12-01 22:01:00       Ayush Chamoli
# 4 2022-12-01 22:01:00          Akshat Rai
#
#                                              Message  Year
# 0  Messages and calls are end-to-end encrypted. N...  2022
# 1                                  <Media omitted>\n  2022
# 2                                           Thanks\n  2022
# 3                                       Sorry bhai\n  2022
# 4                                       No problem\n  2022

# %%
df["Dates"].dt.month_name()
# Out:
# 0       December
# 1       December
# 2       December
# 3       December
# 4       December
#           ...
# 2630      August
# 2631      August
# 2632      August
# 2633      August
# 2634      August
# Name: Dates, Length: 2635, dtype: object

# %%
df["Month"]=df["Dates"].dt.month_name()

# %%
df["Day"]=df["Dates"].dt.day

# %%
df["Hour"]=df["Dates"].dt.hour

# %%
df["Minute"]=df["Dates"].dt.minute

# %%
df.head()
# Out:
#                 Dates               Users  \
# 0 2022-12-01 22:00:00  Group Notification
# 1 2022-12-01 22:00:00       Ayush Chamoli
# 2 2022-12-01 22:01:00          Akshat Rai
# 3 2022-12-01 22:01:00       Ayush Chamoli
# 4 2022-12-01 22:01:00          Akshat Rai
#
#                                              Message  Year     Month  Day  \
# 0  Messages and calls are end-to-end encrypted. N...  2022  December    1
# 1                                  <Media omitted>\n  2022  December    1
# 2                                           Thanks\n  2022  December    1
# 3                                       Sorry bhai\n  2022  December    1
# 4                                       No problem\n  2022  December    1
#
#    Hour  Minute
# 0    22       0
# 1    22       0
# 2    22       1
# 3    22       1
# 4    22       1
